# %% [markdown]
# # **Movies On Streaming Platforms Analysis**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
mov=pd.read_csv('https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/refs/heads/master/MoviesOnStreamingPlatforms_updated.csv')
mov
# Out:
#        Unnamed: 0     ID                           Title  Year  Age  IMDb  \
# 0               0      1                       Inception  2010  13+   8.8
# 1               1      2                      The Matrix  1999  18+   8.7
# 2               2      3          Avengers: Infinity War  2018  13+   8.5
# 3               3      4              Back to the Future  1985   7+   8.5
# 4               4      5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...           ...    ...                             ...   ...  ...   ...
# 16739       16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740       16740  16741                  The Poof Point  2001   7+   4.7
# 16741       16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742       16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743       16743  16744                In Beaver Valley  1950  NaN   NaN
#
#       Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# ...

# %% [markdown]
# # **DESCRIPTION OF THE COLUMNS**
#
# * ID: Unique identifier for each movie.
# * Title: The title of the movie
# * Year: The year the movie was released
# * Age: The age rating of the movie (e.g., 18+, 7+, all).
# * IMDb: The IMDb rating of the movie
# * Rotten Tomatoes: A normalized score (0-100) reflecting the overall percentage of positive reviews from critics
# * Netflix: Whether the movie is available on Netflix (1 for Yes, 0 for No).
# * Hulu: Whether the movie is available on Hulu (1 for Yes, 0 for No).
# * Prime Video: Whether the movie is available on Prime Video (1 for Yes, 0 for No).
# * Disney+: Whether the movie is available on Disney+ (1 for Yes, 0 for No).
# * Directors: The director(s) of the movie.
# * Genres: A list of categories classifying the movie's
# style and content.
# * Country: The country of origin of the movie.
# * Language: The language(s) of the movie.
# * Runtime: The duration of the movie in minutes.

# %%
mov.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes',
#        'Netflix', 'Hulu', 'Prime Video', 'Disney+', 'Type', 'Directors',
#        'Genres', 'Country', 'Language', 'Runtime'],
#       dtype='object')

# %%
mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       16744 non-null  int64
#  1   ID               16744 non-null  int64
#  2   Title            16744 non-null  object
#  3   Year             16744 non-null  int64
#  4   Age              7354 non-null   object
#  5   IMDb             16173 non-null  float64
#  6   Rotten Tomatoes  5158 non-null   object
#  7   Netflix          16744 non-null  int64
#  8   Hulu             16744 non-null  int64
#  9   Prime Video      16744 non-null  int64
#  10  Disney+          16744 non-null  int64
#  11  Type             16744 non-null  int64
#  12  Directors        16018 non-null  object
#  13  Genres           16469 non-null  object
#  14  Country          16309 non-null  object
#  15  Language         16130 non-null  object
#  16  Runtime          16152 non-null  float64
# ...

# %%
mov.describe()
# Out:
#          Unnamed: 0            ID          Year          IMDb       Netflix  \
# count  16744.000000  16744.000000  16744.000000  16173.000000  16744.000000
# mean    8371.500000   8372.500000   2003.014035      5.902751      0.212613
# std     4833.720789   4833.720789     20.674321      1.347867      0.409169
# min        0.000000      1.000000   1902.000000      0.000000      0.000000
# 25%     4185.750000   4186.750000   2000.000000      5.100000      0.000000
# 50%     8371.500000   8372.500000   2012.000000      6.100000      0.000000
# 75%    12557.250000  12558.250000   2016.000000      6.900000      0.000000
# max    16743.000000  16744.000000   2020.000000      9.300000      1.000000
#
#                Hulu   Prime Video       Disney+     Type       Runtime
# count  16744.000000  16744.000000  16744.000000  16744.0  16152.000000
# mean       0.053930      0.737817      0.033684      0.0     93.413447
# std        0.225886      0.439835      0.180419      0.0     28.219222
# ...

# %% [markdown]
# # Data Cleaning

# %%
mov.isnull()
# Out:
#        Unnamed: 0     ID  Title   Year    Age   IMDb  Rotten Tomatoes  \
# 0           False  False  False  False  False  False            False
# 1           False  False  False  False  False  False            False
# 2           False  False  False  False  False  False            False
# 3           False  False  False  False  False  False            False
# 4           False  False  False  False  False  False            False
# ...           ...    ...    ...    ...    ...    ...              ...
# 16739       False  False  False  False   True  False             True
# 16740       False  False  False  False  False  False             True
# 16741       False  False  False  False   True  False             True
# 16742       False  False  False  False   True  False             True
# 16743       False  False  False  False   True   True             True
#
#        Netflix   Hulu  Prime Video  Disney+   Type  Directors  Genres  \
# ...

# %%
mov.drop('Unnamed: 0', axis=1, inplace=True)

# %%
mov['Directors'] = mov['Directors'].fillna('Unknown')

# %%
mov['Genres']=mov['Genres'].fillna('Unknown')

# %%
mov['Country']=mov['Country'].fillna('Unknown')

# %%
mov['Language']=mov['Language'].fillna('Unknown')

# %%
mov['IMDb']=mov['IMDb'].fillna(5.902751)

# %%
mov[mov['Runtime'].isnull()]
mov['Runtime']=mov['Runtime'].fillna(93.413447)

# %%
pd.unique(mov['Type'])
# Out:
# array([0])

# %%
mov.drop('Type', axis=1, inplace=True)

# %% [markdown]
# # Feature Engineering

# %%
mov[mov['Rotten Tomatoes'].isnull()]
# Out:
#           ID                                  Title  Year  Age      IMDb  \
# 373      374                           A Wednesday!  2008  NaN  8.100000
# 564      565                        Rang De Basanti  2006  13+  8.200000
# 592      593  Cowspiracy: The Sustainability Secret  2014  NaN  8.300000
# 605      606                         Dil Chahta Hai  2001  all  8.100000
# 620      621                       Paan Singh Tomar  2012   7+  8.200000
# ...      ...                                    ...   ...  ...       ...
# 16739  16740              The Ghosts of Buxley Hall  1980  NaN  6.200000
# 16740  16741                         The Poof Point  2001   7+  4.700000
# 16741  16742                  Sharks of Lost Island  2013  NaN  5.700000
# 16742  16743                     Man Among Cheetahs  2017  NaN  6.600000
# 16743  16744                       In Beaver Valley  1950  NaN  5.902751
#
#       Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  \
# ...

# %%
mov['Rotten Tomatoes'] = mov['Rotten Tomatoes'].astype(str)

mov['Rotten Tomatoes'] = mov['Rotten Tomatoes'].str.replace('%', '', regex=True)

mov['Rotten Tomatoes'] = pd.to_numeric(mov['Rotten Tomatoes'], errors='coerce')

mov['Rotten Tomatoes']
# Out:
# 0        87.0
# 1        87.0
# 2        84.0
# 3        96.0
# 4        97.0
#          ...
# 16739     NaN
# 16740     NaN
# 16741     NaN
# 16742     NaN
# 16743     NaN
# Name: Rotten Tomatoes, Length: 16744, dtype: float64

# %%
mov['Rotten Tomatoes'].fillna(mov['Rotten Tomatoes'].mean(), inplace=True)

# %%
mov['Age'].unique()
# Out:
# array(['13+', '18+', '7+', nan, 'all', '16+'], dtype=object)

# %%
mov['Age'] = mov['Age'].replace({'all': '0'})

# %%
mov['Age'] = mov['Age'].astype(str)
mov['Age'] = mov['Age'].str.extract(r'(\d+)', expand=False)

mov['Age'] = pd.to_numeric(mov['Age'], errors='coerce').astype('Int64')

# %%
mov['Age']=mov['Age'].fillna(13)

# %%
Platform = ['Netflix', 'Hulu', 'Prime Video', 'Disney+']
mov_melted = mov.melt(id_vars='Title', value_vars=Platform, var_name='Platforms', value_name='Availability')
mov_melted
# Out:
#                                 Title Platforms  Availability
# 0                           Inception   Netflix             1
# 1                          The Matrix   Netflix             1
# 2              Avengers: Infinity War   Netflix             1
# 3                  Back to the Future   Netflix             1
# 4      The Good, the Bad and the Ugly   Netflix             1
# ...                               ...       ...           ...
# 66971       The Ghosts of Buxley Hall   Disney+             1
# 66972                  The Poof Point   Disney+             1
# 66973           Sharks of Lost Island   Disney+             1
# 66974              Man Among Cheetahs   Disney+             1
# 66975                In Beaver Valley   Disney+             1
#
# [66976 rows x 3 columns]

# %%
Platform=['Netflix','Hulu','Prime Video','Disney+']
mov['count_platforms']=mov[Platform].sum(axis=1)
mov['count_platforms']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        2
#         ..
# 16739    1
# 16740    1
# 16741    1
# 16742    1
# 16743    1
# Name: count_platforms, Length: 16744, dtype: int64

# %%
mov['Genres'].str.split(',').explode().value_counts()
# Out:
# Genres
# Drama          7227
# Comedy         4637
# Thriller       3354
# Action         2683
# Documentary    2546
# Romance        2359
# Horror         2201
# Crime          1833
# Adventure      1778
# Family         1514
# Mystery        1274
# Sci-Fi         1228
# Fantasy        1089
# Biography       821
# History         715
# Animation       711
# Music           667
# War             539
# Western         499
# Sport           404
# Musical         401
# Short           386
# Unknown         275
# News            105
# Film-Noir        79
# Reality-TV       22
# Talk-Show        19
# Game-Show         7
# Name: count, dtype: int64

# %%
mov.drop_duplicates(keep=False,inplace=False)
# Out:
#           ID                           Title  Year  Age      IMDb  \
# 0          1                       Inception  2010   13  8.800000
# 1          2                      The Matrix  1999   18  8.700000
# 2          3          Avengers: Infinity War  2018   13  8.500000
# 3          4              Back to the Future  1985    7  8.500000
# 4          5  The Good, the Bad and the Ugly  1966   18  8.800000
# ...      ...                             ...   ...  ...       ...
# 16739  16740       The Ghosts of Buxley Hall  1980   13  6.200000
# 16740  16741                  The Poof Point  2001    7  4.700000
# 16741  16742           Sharks of Lost Island  2013   13  5.700000
# 16742  16743              Man Among Cheetahs  2017   13  6.600000
# 16743  16744                In Beaver Valley  1950   13  5.902751
#
#        Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  \
# 0            87.000000        1     0            0        0
# ...

# %%
pd.to_datetime('06-dec-2024')
# Out:
# Timestamp('2024-12-06 00:00:00')

# %%
mov.sort_values('Year',inplace=False)
# Out:
#           ID                                   Title  Year  Age      IMDb  \
# 4467    4468                      A Trip to the Moon  1902    0  8.200000
# 8795    8796            From the Manger to the Cross  1912    7  5.700000
# 9917    9918                   Fatty Joins the Force  1913   13  5.300000
# 10170  10171                         The Speed Kings  1913   13  5.000000
# 6257    6258                        A Fool There Was  1915   13  5.800000
# ...      ...                                     ...   ...  ...       ...
# 3463    3464             Har Kisse Ke Hisse Kaamyaab  2020    7  5.902751
# 2795    2796  Captain Underpants: Epic Choice-o-rama  2020   13  6.300000
# 2110    2111           Tom Papa: You're Doing Great!  2020   13  7.100000
# 1739    1740              The Stand at Paxton County  2020   13  6.400000
# 3417    3418                              John Henry  2020   18  3.500000
#
#        Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+       Directors  \
# ...

# %%
mov
# Out:
#           ID                           Title  Year  Age      IMDb  \
# 0          1                       Inception  2010   13  8.800000
# 1          2                      The Matrix  1999   18  8.700000
# 2          3          Avengers: Infinity War  2018   13  8.500000
# 3          4              Back to the Future  1985    7  8.500000
# 4          5  The Good, the Bad and the Ugly  1966   18  8.800000
# ...      ...                             ...   ...  ...       ...
# 16739  16740       The Ghosts of Buxley Hall  1980   13  6.200000
# 16740  16741                  The Poof Point  2001    7  4.700000
# 16741  16742           Sharks of Lost Island  2013   13  5.700000
# 16742  16743              Man Among Cheetahs  2017   13  6.600000
# 16743  16744                In Beaver Valley  1950   13  5.902751
#
#        Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  \
# 0            87.000000        1     0            0        0
# ...

# %%
mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               16744 non-null  int64
#  1   Title            16744 non-null  object
#  2   Year             16744 non-null  int64
#  3   Age              16744 non-null  Int64
#  4   IMDb             16744 non-null  float64
#  5   Rotten Tomatoes  16744 non-null  float64
#  6   Netflix          16744 non-null  int64
#  7   Hulu             16744 non-null  int64
#  8   Prime Video      16744 non-null  int64
#  9   Disney+          16744 non-null  int64
#  10  Directors        16744 non-null  object
#  11  Genres           16744 non-null  object
#  12  Country          16744 non-null  object
#  13  Language         16744 non-null  object
#  14  Runtime          16744 non-null  float64
#  15  count_platforms  16744 non-null  int64
# ...

# %% [markdown]
# # Group by and Aggregate Methods

# %%
grp_obj=mov.groupby('Genres')
grp_obj.groups
# Out:
# {'Action': [1068, 1996, 2111, 2256, 2429, 2532, 2565, 2585, 2594, 2631, 2679, 2684, 2829, 2835, 3033, 3037, 3248, 3285, 3401, 4065, 4089, 4421, 4919, 5824, 6967, 7097, 7394, 7810, 8361, 8464, 8506, 8604, 8632, 8942, 8948, 9382, 9469, 9496, 9690, 9693, 9723, 10014, 10108, 10127, 10157, 10330, 10414, 10487, 10542, 10738, 10874, 10999, 11254, 11256, 11261, 11300, 11364, 11435, 11452, 11611, 11749, 11760, 11815, 11865, 11946, 11984, 12098, 12133, 12173, 12196, 12290, 12359, 12395, 12459, 12665, 12677, 12855, 12870, 13060, 13083, 13239, 13275, 13278, 13312, 13364, 13450, 13462, 13632, 13728, 13760, 13847, 13874, 14070, 14084, 14099, 14103, 14117, 14237, 14284, 14316, ...], 'Action,Adventure': [8, 16, 44, 219, 1657, 2996, 3245, 3565, 4392, 5796, 6538, 6762, 7058, 7128, 9205, 9252, 9823, 10394, 11119, 11123, 11550, 11785, 11876, 12083, 12361, 12587, 12598, 13043, 13136, 13216, 13243, 13589, 13914, 14106, 14172, 14356, 14375, 14510, 14656, 14947, 14961, 15059, 15256, 15439, 15474, 15502, 157
# ...

# %%
grp_obj=mov.groupby(['Directors','Country'])
grp_obj.groups
# Out:
# {('A'Ali de Sousa', 'United States'): [13239], ('A. Bhimsingh', 'India'): [12719], ('A. Edward Sutherland', 'United States'): [5499, 8207, 11886], ('A. Edward Sutherland,John Rawlins', 'United States'): [10582], ('A. Fishman', 'United States,Denmark,Netherlands,Sweden,United Kingdom'): [12638], ('A. Jagadesh', 'India'): [11158], ('A. Majid', 'India'): [10711], ('A. Salaam', 'India'): [3423], ('A. Todd Smith', 'United States'): [7517], ('A. Troy Thomas', 'United States'): [10987], ('A.D. Calvo', 'United States'): [11068], ('A.J. Bond', 'Canada'): [14625], ('A.J. Eaton', 'United States'): [3815], ('A.J. Martinson', 'United States'): [9517], ('A.J. Mattioli', 'United States'): [9155, 11282, 14049], ('A.L. Abanindran', 'India'): [13080], ('A.L. Vijay', 'India'): [2608, 2887, 9319], ('A.R. Murugadoss', 'India'): [1611, 6072], ('A.T. White', 'United States'): [3878], ('AJ Wedding', 'United States'): [15777], ('Aadish Keluskar', 'India'): [2766], ('Aamir Khan,Amole Gupte', 'India'): [38], (
# ...

# %%
grp_obj=mov.groupby(['Country','Language'])
grp_obj.get_group(('India','Hindi'))
# Out:
#           ID                     Title  Year  Age  IMDb  Rotten Tomatoes  \
# 34        35                    Dangal  2016    7   8.4        88.000000
# 133      134                    Barfi!  2012    0   8.1        86.000000
# 154      155                    Haider  2014   13   8.1        86.000000
# 155      156                    Padman  2018   13   7.9       100.000000
# 171      172                Article 15  2019   13   8.3        89.000000
# ...      ...                       ...   ...  ...   ...              ...
# 15612  15613                     Drona  2008   13   2.0        65.428461
# 15692  15693  Shortkut - The Con Is On  2009   13   3.4        65.428461
# 15784  15785            Gang Of Ghosts  2014   13   3.6        65.428461
# 15795  15796   Maan Gaye Mughal-e-Azam  2008   13   3.1        65.428461
# 15822  15823                   Machine  2007   18   2.7        65.428461
#
#        Netflix  Hulu  Prime Video  Disney+  \
# 34           1     0            0        0
# ...

# %%
gp_obj = mov.groupby(['Country'])
a = gp_obj.get_group(('India',))
result = a[['Directors', 'Language']]
result
# Out:
#                                                Directors  \
# 11                                       Rajkumar Hirani
# 34                                         Nitesh Tiwari
# 38                                Aamir Khan,Amole Gupte
# 81                                    Ashutosh Gowariker
# 88                                        S.S. Rajamouli
# ...                                                  ...
# 15820                                  Ujjwal Chatterjee
# 15822  Abbas Alibhai Burmawalla,Mastan Alibhai Burmaw...
# 15854                                             Anuraj
# 16064                              Tammareddy Bharadwaja
# 16735                                            Unknown
#
#                         Language
# 11                 Hindi,English
# 34                         Hindi
# 38                 Hindi,English
# 81     Hindi,English,Awadhi,Urdu
# 88                  Telugu,Tamil
# ...                          ...
# 15820         Hindi,English,Urdu
# ...

# %%
grp_obj=mov.groupby('Language')
grp_obj.groups
grp_obj.get_group('Chinese,English')
# Out:
#           ID                           Title  Year  Age  IMDb  \
# 5409    5410                       Pali Road  2016    7   7.2
# 12749  12750  Boonie Bears: Homeward Journey  2013   13   5.6
# 13903  13904                           Taven  2015   13   3.0
# 15289  15290                The Purple Onion  2017   13   5.4
#
#        Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+         Directors  \
# 5409         55.000000        0     0            1        0      Jonathan Lim
# 12749        65.428461        0     0            1        0        Fuyuan Liu
# 13903        65.428461        0     0            1        0        Teli Hsueh
# 15289        65.428461        0     0            1        0  Matt Szymanowski
#
#                                        Genres               Country  \
# 5409   Drama,Fantasy,Mystery,Romance,Thriller   China,United States
# 12749       Animation,Adventure,Comedy,Family                 China
# ...

# %%
director_ratings = mov.groupby('Directors')[['IMDb', 'Rotten Tomatoes']].mean()
filtered_directors = director_ratings[mov['Directors'].value_counts() >= 5]
filtered_directors
# Out:
# <ipython-input-36-fb3ecaee3d1f>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_directors = director_ratings[mov['Directors'].value_counts() >= 5]
#                                                         IMDb  Rotten Tomatoes
# Directors
# Abbas Alibhai Burmawalla,Mastan Alibhai Burmawalla  6.166667        65.428461
# Abel Ferrara                                        5.166667        59.809487
# Adam Rifkin                                         5.860000        65.971384
# Alan Bradley                                        5.761100        65.428461
# Albert Herman                                       5.280000        65.428461
# ...                                                      ...              ...
# William Wyler                                       7.233333        80.547564
# Woo-Ping Yuen                                       6.300000        54.285692
# ...

# %%
grp = mov_melted.groupby('Platforms')
a=grp.get_group('Hulu')
b=grp.get_group('Netflix')
c=pd.concat([a,b])
c = pd.merge(c, mov[['Title', 'IMDb']], on='Title', how='left')
c[['Title','IMDb']]
# Out:
#                                 Title      IMDb
# 0                           Inception  8.800000
# 1                          The Matrix  8.700000
# 2              Avengers: Infinity War  8.500000
# 3                  Back to the Future  8.500000
# 4      The Good, the Bad and the Ugly  8.800000
# ...                               ...       ...
# 33483       The Ghosts of Buxley Hall  6.200000
# 33484                  The Poof Point  4.700000
# 33485           Sharks of Lost Island  5.700000
# 33486              Man Among Cheetahs  6.600000
# 33487                In Beaver Valley  5.902751
#
# [33488 rows x 2 columns]

# %%
grp_obj = mov.groupby('Age')['IMDb'].mean()
grp_obj
# Out:
# Age
# 0     6.168838
# 7     6.069026
# 13    5.965881
# 16    5.516259
# 18    5.610367
# Name: IMDb, dtype: float64

# %%
mov['Rotten Tomatoes'].corr(mov['Age'])
# Out:
# -0.03865963298077544

# %% [markdown]
# Observation: There is a weak negative correlation between Rotten Tomatoes scores and movie age ratings.

# %%
mov['Runtime'].corr(mov['IMDb'])
# Out:
# 0.08621156239526342

# %% [markdown]
# Observation: There is a weak positive correlation between movie runtime and IMDb rating.

# %% [markdown]
# # Some Questions

# %% [markdown]
# **1.What is the average Rotten Tomatoes score for movies with an age rating of 18+?**

# %%
mov[mov['Age'] >= 18]['Rotten Tomatoes'].mean()
# Out:
# 62.845490669847216

# %% [markdown]
# Observation:The average Rotten Tomatoes score for movies with an age rating of 18+ is 62.845490669847216

# %% [markdown]
# **2.What is the total number of movies available on each platform?**

# %%
platform_counts=mov[['Netflix', 'Hulu', 'Prime Video', 'Disney+']].sum()
platform_counts
# Out:
# Netflix         3560
# Hulu             903
# Prime Video    12354
# Disney+          564
# dtype: int64

# %% [markdown]
# observation:The above output shows the total number of movies available on each platform

# %% [markdown]
# **3.How many movies have a Rotten Tomatoes score higher than 90% and an IMDb rating above 8.5?**

# %%
len(mov[(mov['Rotten Tomatoes'] > 90) & (mov['IMDb'] > 8.5)])
# Out:
# 10

# %% [markdown]
# Observation:10 movies have a Rotten Tomatoes score higher than 90% and an IMDb rating above 8.5

# %% [markdown]
# **4.What is the distribution of movies across different age ratings?**

# %%
age_counts=mov['Age'].value_counts()
age_counts
# Out:
# Age
# 13    10645
# 18     3474
# 7      1462
# 0       843
# 16      320
# Name: count, dtype: Int64

# %% [markdown]
# Observation:The above output shows the prevalence of movies targeting different age groups.

# %% [markdown]
# **5.what is most common IMDb ratings in Netflix platform?**

# %%
mov[mov['Netflix'] == 1]['IMDb'].mode()[0]
# Out:
# 6.5

# %% [markdown]
# observation:6.5 is the most common IMDb ratings in Netflix platform.

# %% [markdown]
# **6.How many movies were released each year?**

# %%
mov['Year'].value_counts().sort_index()
# Out:
# Year
# 1902       1
# 1912       1
# 1913       2
# 1915       4
# 1916       1
#         ...
# 2016    1206
# 2017    1401
# 2018    1285
# 2019     689
# 2020     147
# Name: count, Length: 109, dtype: int64

# %% [markdown]
# **7.What are the top 5 most common movie genres?**

# %%
genre_counts=mov['Genres'].str.split(',').explode().value_counts().head(5)
genre_counts
# Out:
# Genres
# Drama          7227
# Comedy         4637
# Thriller       3354
# Action         2683
# Documentary    2546
# Name: count, dtype: int64

# %% [markdown]
# **8.What is the average Rotten Tomatoes score for movies in each genres?**

# %%
mov.groupby('Genres')['Rotten Tomatoes'].mean().sort_values(ascending=False)
# Out:
# Genres
# Adventure,Drama,Family,Western                  100.0
# Short,Action,Adventure,Comedy,Fantasy,Sci-Fi    100.0
# Short,Comedy,Music,Sport                        100.0
# Action,Drama,Fantasy,Sci-Fi                     100.0
# Documentary,Comedy,History,Thriller             100.0
#                                                 ...
# Comedy,Crime,Drama,Mystery,Romance,Thriller      11.0
# Animation,Comedy,Family,Horror                   10.0
# Comedy,Fantasy,Horror,Sci-Fi                     10.0
# Action,Adventure,Comedy,Mystery                   9.0
# Adventure,Comedy,Family,Fantasy,Romance           5.0
# Name: Rotten Tomatoes, Length: 1910, dtype: float64

# %% [markdown]
# **9.What is the correlation between Rotten Tomatoes score and the number of platforms?**

# %%
mov[['Rotten Tomatoes', 'count_platforms']].corr()
# Out:
#                  Rotten Tomatoes  count_platforms
# Rotten Tomatoes         1.000000        -0.036411
# count_platforms        -0.036411         1.000000

# %% [markdown]
# observation : There is a weak negative correlation between Rotten Tomatoes score and the number of platforms.

# %% [markdown]
# # Data visualization

# %% [markdown]
# **Distribution of movies across different age ratings**

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Age', data=mov, hue='Age', palette='rainbow', legend=False)
plt.title('Distribution of Movies by Age Rating')
plt.xlabel('Age Rating')
plt.ylabel('Number of Movies')
# Out:
# Text(0, 0.5, 'Number of Movies')

# %% [markdown]
# **Distribution of movies by genre (top 10 genres)**

# %%
plt.figure(figsize=(12, 6))
top_genres = mov['Genres'].str.split(',').explode().value_counts().head(10).index
sns.countplot(x='Genres', data=mov[mov['Genres'].isin(top_genres)], order=top_genres)
plt.title('Distribution of Movies by Top 10 Genres')
plt.xlabel('Genre')
plt.ylabel('Number of Movies')
# Out:
# Text(0, 0.5, 'Number of Movies')

# %% [markdown]
# **Distribution of IMDb ratings for movies in the dataset**

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(x='IMDb', data=mov)
plt.title('Distribution of IMDb Ratings')
plt.xlabel('IMDb Rating')
plt.ylabel('Density')
plt.grid()

# %% [markdown]
# **Distribution of Rotten Tomatoes scores for movies on Netflix**

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(x='Age', data=mov[mov['Netflix'] == 1],fill=True)
plt.title('Distribution of Rotten Tomatoes Scores for Movies on Netflix')
plt.xlabel('Rotten Tomatoes Score')
plt.ylabel('Density')
plt.grid()

# %% [markdown]
# **Movie runtimes distributed**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(x='Runtime', data=mov, bins=50)
plt.title('Distribution of Movie Runtimes')
plt.xlabel('Runtime (minutes)')
plt.ylabel('Frequency')
plt.grid()

# %% [markdown]
# **Distribution of movie release years (with custom bins)**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(x='Year', data=mov, bins=range(1900, 2021, 5))  # Bins every 5 years
plt.title('Distribution of Movie Release Years (Decades)')
plt.xlabel('Release Year')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# **Relationship between IMDb ratings and Rotten Tomatoes scores for movies**

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='IMDb', y='Rotten Tomatoes', data=mov)
plt.title('IMDb Rating vs. Rotten Tomatoes Score')
plt.xlabel('IMDb Rating')
plt.ylabel('Rotten Tomatoes Score')
# Out:
# Text(0, 0.5, 'Rotten Tomatoes Score')

# %% [markdown]
# **Relationship between movie runtime and IMDb rating, colored by age rating**

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Runtime', y='IMDb', data=mov, hue='Age',palette='rainbow')
plt.title('Movie Runtime vs. IMDb Rating, Colored by Age Rating')
plt.xlabel('Runtime (minutes)')
plt.ylabel('IMDb Rating')
# Out:
# Text(0, 0.5, 'IMDb Rating')

# %% [markdown]
# **IMDb ratings and Rotten Tomatoes scores vary together for movies**

# %%
sns.jointplot(x='IMDb', y='Rotten Tomatoes', data=mov)

plt.show()

# %% [markdown]
# **Joint distribution of IMDb rating and Rotten Tomatoes score, with a regression line**

# %%
sns.jointplot(x='IMDb', y='Age', data=mov, kind='reg')
plt.show()

# %% [markdown]
# **Average IMDb rating by country (top 10 countries)**

# %%
plt.figure(figsize=(12, 6))
top_countries = mov['Country'].str.split(',').explode().value_counts().head(10).index
avg_ratings = mov[mov['Country'].isin(top_countries)].groupby('Country')['IMDb'].mean().sort_values(ascending=False)
sns.barplot(x='Country', y='IMDb', data=avg_ratings.reset_index(inplace=False))
plt.title('Average IMDb Rating by Top 10 Countries')
plt.xlabel('Country')
plt.ylabel('Average IMDb Rating')
# Out:
# Text(0, 0.5, 'Average IMDb Rating')

# %% [markdown]
# **Total Number of Movies on Each Platform**

# %%
plt.figure(figsize=(10, 6))
platform_counts = mov[['Netflix', 'Hulu', 'Prime Video', 'Disney+']].sum()
sns.barplot(x=platform_counts.index, y=platform_counts.values,palette='rainbow')
plt.title('Total Number of Movies on Each Platform')
plt.xlabel('Platform')
plt.ylabel('Number of Movies')
plt.show()
# Out:
# <ipython-input-61-34958de978d0>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=platform_counts.index, y=platform_counts.values,palette='rainbow')

# %% [markdown]
# **IMDb ratings vary across different age ratings**

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Age', y='IMDb', data=mov)
plt.title('IMDb Ratings by Age Rating')
plt.xlabel('Age Rating')
plt.ylabel('IMDb Rating')
plt.show()

# %% [markdown]
# **Relationship between IMDb ratings and Rotten Tomatoes scores change for different age ratings**

# %%
sns.lmplot(x='IMDb', y='Rotten Tomatoes', data=mov, hue='Age', height=7)
plt.title('IMDb Rating vs. Rotten Tomatoes Score by Age Rating')
plt.xlabel('IMDb Rating')
plt.ylabel('Rotten Tomatoes Score')
plt.show()

# %% [markdown]
# **Distribution of Movies Across Platforms**

# %%
platform_counts = mov[['Netflix', 'Hulu', 'Prime Video', 'Disney+']].sum()

plt.figure(figsize=(8, 8))
plt.pie(platform_counts, labels=platform_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Movies Across Platforms')
# Out:
# Text(0.5, 1.0, 'Distribution of Movies Across Platforms')

# %% [markdown]
# **Distribution of Movies Across Age Ratings**

# %%
age_counts = mov['Age'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(age_counts, labels=age_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Movies Across Age Ratings')
# Out:
# Text(0.5, 1.0, 'Distribution of Movies Across Age Ratings')

# %% [markdown]
# **Correlation Matrix of Numerical Features**

# %%
numerical_features = ['Year', 'IMDb', 'Rotten Tomatoes', 'Runtime']
correlation_matrix = mov[numerical_features].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix of Numerical Features')

# %% [markdown]
# # Conclusion

# %% [markdown]
# * **Platform Distribution:** Prime Video has the most extensive movie library, whereas Disney+ has the smallest
# * **Genre Popularity:** Drama, Comedy, and Action are the most prevalent genres.
# * **Age Ratings:** A significant portion of movies is suitable for all ages or viewers aged 13 and above.
# * **Ratings:** IMDb and Rotten Tomatoes scores show a moderate positive correlation, suggesting a general agreement on movie quality.
# * **Runtime:** Movie runtimes typically range between 80 to 120 minutes.
# * **Release Years:** There is a trend of increasing movie releases over the years, with a recent increase in the early 2000s and 2010s.
